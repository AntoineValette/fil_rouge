# %%
import pandas as pd
from IPython.display import display

# Chemin vers le fichier CSV
file_path = "../../crunchbase/organizations.csv"

# Charger le CSV dans un DataFrame
org = pd.read_csv(file_path)

# Afficher le DataFrame
display(org)
# Out:
#                                          uuid  \
# 0        e1393508-30ea-8a36-3f96-dd3226033abd
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0
# 3        df662812-7f97-0b43-9d3e-12f64f504fbb
# 4        60485007-8856-bbac-aa1b-c535c41f5f47
# ...                                       ...
# 3630615  dfa356a4-967c-4640-b2c4-012ae959f7ab
# 3630616  cb789bcf-b58b-448c-95c7-88c775fa375c
# 3630617  086ef382-3792-4cde-98ac-0565bcc11730
# 3630618  8c4daf3b-342e-4923-a839-98c71ec11cf2
# 3630619  65e0bde5-24de-4f4f-a8c5-c92e70735229
#
#                                                       name          type  \
# 0                                                 Wetpaint  organization
# 1                                                     Zoho  organization
# 2                                                     Digg  organization
# 3                                                     Meta  organization
# ...

# %%
# Chemin vers le fichier CSV
file_path = "../../crunchbase/people.csv"

# Charger le CSV dans un DataFrame
ppl = pd.read_csv(file_path)

# Afficher le DataFrame
display(ppl)
# Out:
#                                          uuid    type first_name   last_name  \
# 0        ed13cd36-fe2b-3707-197b-0c2d56e37a71  person        Ben     Elowitz
# 1        5ceca97b-493c-1446-6249-5aaa33464763  person      Kevin    Flaherty
# 2        9f99a98a-aa97-b30b-0d36-db67c1d277e0  person       Raju     Vegesna
# 3        6e1bca72-a865-b518-b305-31214ce2d1b0  person        Ian       Wenig
# 4        80d25c23-9726-9dda-5852-39cdf4810ea5  person        Ron  Gorodetzky
# ...                                       ...     ...        ...         ...
# 1292327  b382924c-7825-494e-86ec-85f992116810  person     Karman      Suyama
# 1292328  d39958b8-9439-4ee8-8558-d6ca953ffc27  person       Evan     Galasso
# 1292329  9f5d8f3b-5569-4429-9860-f3d7ca773612  person     Arthur      Nsenga
# 1292330  723dc85c-4e8c-460e-8a78-a58ce1ad4cbf  person   Nicholas       Hakes
# 1292331  d3e35dd1-486d-4663-84c0-76a9176b5381  person     Hannah     Cirillo
#
# ...

# %%
# Compter le nombre de valeurs uniques dans la colonne "featured_job_title"
unique_count = ppl["featured_job_title"].nunique()
print("Nombre de valeurs uniques :", unique_count)
# Out:
# Nombre de valeurs uniques : 256078

# %%
# Afficher les valeurs uniques de la colonne "featured_job_title"
unique_values = ppl["featured_job_title"].unique()
for job_title in unique_values:
    print(job_title)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Co-Founder and Chief Curator of La Colección
# Co-Founder, CEO, Owner, and Executive Producer
# Founder & Owner/Authorised approved accountant
# Vice President Human Resources, Administration
# Install Coordinator
# Chief Financial Officer, Owner
# Founder and Previous Owner
# Software Developer and Malware Analyst
# Head of Digital Banking and Marketing - Executive Committee (EXCO) Member
# Joint Owner and Marketing Manager
# consultant/previous CEO
# President, Castle & Cooke Building Materials
# Co-Founder, Co-Owner, and Executive Partner
# Head of Products & Mass Segment
# Partner, Certified Public Accountant, and Certified Fraud Examiner
# ...

# %%
df = ppl[(ppl['featured_job_organization_name'] == "Meta") & (ppl['first_name'] == "Mark")]
display(df)
# Out:
#                                         uuid    type first_name   last_name  \
# 5       a01b8d46-d311-3333-7c34-aa3ae9c03f22  person       Mark  Zuckerberg
# 4078    e8bc4eb6-cb09-5761-a67e-a8e571ad332d  person       Mark      Cramer
# 34138   a9bbea61-8ceb-b65d-63cf-a41b3d9610d9  person       Mark    Westling
# 34604   7ada7eb1-f8e3-efed-0de0-54196f2438d8  person       Mark      Rabkin
# 85929   47b88b23-a728-8074-5a6c-c72339c3fba1  person       Mark   Tsimelzon
# 190093  4957b17b-1126-eeac-a155-d427f9abfa2b  person       Mark         Jen
# 299017  e2ce6d5c-9d23-7e17-c952-d1038367615d  person       Mark     Hammell
# 749558  8645babc-0790-4475-9e40-bd27eff8792b  person       Mark   Mucchetti
#
#                                                    cb_url  \
# 5       https://www.crunchbase.com/person/mark-zuckerb...
# 4078    https://www.crunchbase.com/person/mark-cramer?...
# 34138   https://www.crunchbase.com/person/mark-westlin...
# ...

# %%
df=org[(org['primary_role']!="company")]
display(df)
# Out:
#                                          uuid                    name  \
# 21       3d9e4070-1a25-7491-d1a9-17bec9f6361b       Hutchison Whampoa
# 22       5858c937-702e-c278-1725-2b5e02471482    Cheung Kong Holdings
# 37       30b3efdf-6024-804d-ea55-c4d1a8dfc86c           Goldman Sachs
# 51       ac88d380-ab57-cf90-a05b-e39ff838c6f9                   Tapuz
# 91       e2a753f1-1247-b2f9-1f97-c5f2c1ec7b0a              Legg Mason
# ...                                       ...                     ...
# 3629797  4e3a2227-cb47-4c69-b980-362a8279e83e                   Taska
# 3630039  dd133c68-ca16-4e01-b3d4-edd2c3789a37  Hengxing New Materials
# 3630108  67cce4fd-acb7-4d9b-88ae-4a0e9c611aa2      Rock Yard Ventures
# 3630236  802ec495-c8de-42ec-9378-7d81c083bee5          NexenaiCapital
# 3630344  6e86a96b-c00b-48ba-96c5-06134f7fa360            UBC Okanagan
#
#                  type primary_role  \
# 21       organization     investor
# 22       organization     investor
# ...

# %%
# Afficher les valeurs uniques de la colonne "featured_job_title"
unique_values = org["primary_role"].unique()
for primary_roles in unique_values:
    print(primary_roles)
# Out:
# company
# investor
# school

# %%
df= org[(org["domain"]=="emailprogen.comt.")]
display(df)
# Out:
#                                        uuid         name          type  \
# 72955  158b5bdb-d316-0a44-734a-30f85793735b  Emailprogen  organization
#
#       primary_role                                             cb_url  \
# 72955      company  https://www.crunchbase.com/organization/emailp...
#
#                   domain                 homepage_url  \
# 72955  emailprogen.comt.  http://www.emailprogen.comt
#
#                                                 logo_url facebook_url  \
# 72955  https://images.crunchbase.com/image/upload/t_c...          NaN
#
#                          twitter_url linkedin_url combined_stock_symbols city  \
# 72955  http://twitter.com/Brianwaugh          NaN                    NaN  NaN
#
#       region country_code                       short_description
# 72955    NaN          NaN  Emailprogen an email marketing company

# %%
# Compter le nombre de valeurs uniques dans la colonne "type"
unique_count = ppl["type"].nunique()
print("Nombre de valeurs uniques :", unique_count)
# Out:
# Nombre de valeurs uniques : 1

# %%
nb_na_uuid=ppl["uuid"].isna().sum()
print("Nombre de valeurs na :", nb_na_uuid)

nb_na_linkedin = ppl["linkedin_url"].isna().sum()
print("Nombre de valeurs na :", nb_na_linkedin)
# Out:
# Nombre de valeurs na : 0
# Nombre de valeurs na : 201156

# %%
print(ppl["uuid"].dtype)
# Out:
# object

# %%
df=org[(org['uuid']=="e1a70dca-bbcf-4bad-bfd9-7d88f888f63b")]
display(df)

df2=ppl[(ppl['featured_job_organization_uuid']=="e1a70dca-bbcf-4bad-bfd9-7d88f888f63b")]
display(df2)
# Out:
#                                          uuid        name          type  \
# 1179783  e1a70dca-bbcf-4bad-bfd9-7d88f888f63b  Sumitovant  organization
#
#         primary_role                                             cb_url  \
# 1179783      company  https://www.crunchbase.com/organization/sumito...
#
#                  domain                 homepage_url  \
# 1179783  sumitovant.com  https://www.sumitovant.com/
#
#                                                   logo_url facebook_url  \
# 1179783  https://images.crunchbase.com/image/upload/t_c...          NaN
#
#                                     twitter_url  \
# 1179783  https://twitter.com/sumitovant?lang=en
#
#                                               linkedin_url  \
# 1179783  https://www.linkedin.com/company/sumitovant-bi...
#
#         combined_stock_symbols      city    region country_code  \
# 1179783                    NaN  New York  New York          USA
#
# ...

# %%
unique_count = ppl[ppl["featured_job_title"].str.contains("board", case=False, na=False)]["featured_job_title"].nunique()
print("Nombre de valeurs uniques :", unique_count)
# Out:
# Nombre de valeurs uniques : 5845

# %%
# Afficher les valeurs uniques de la colonne "featured_job_title" qui contiennent "board" (insensible à la casse)
unique_values = ppl["featured_job_title"].unique()
filtered_values = [job_title for job_title in unique_values if pd.notnull(job_title) and "board" in job_title.lower()]

for job_title in filtered_values:
    print(job_title)
# Out:
# Board Member
# Board
# Board Advisor
# Vice Chairman of the Board Directors
# Member of the Board of Directors
# Co-Founder, Investment Committee Member, Board Member
# board of directors
# Member of the Advisory Board
# Advisory Board
# Investor, Advisory Board
# Co-Founder, CTO and Board Member
# Co-Founder,Board Member,CIO & COO
# CEO, President, Board of Directors
# Member Board Of Directors
# CEO , Founder & Board Member
# Board Of Directors
# President & CEO & Board Director
# Board and Audit Committee Member
# Member of the Board of Trustees
# Member of the Technical Advisory Board
# Chief Executive Officer, Member of the Board of Directors
# Co-Founder & Board Member
# Board of Directors & Co-Founder
# Member of Board of Directors
# Board Partner
# Chairman of the Board of Directors
# Chief Operating Officer and Board Member
# Founder, CEO, and Chairman of the Board
# Board of Directors
# Advisory Board Member and Investor
# Director and Board of Directors
# ...

# %%
ppl[ppl['uuid'] == 'a1d2fdc0-14cc-16c6-7502-c4d54b76d831']
# Out:
#                                       uuid    type first_name last_name  \
# 3879  a1d2fdc0-14cc-16c6-7502-c4d54b76d831  person     Steven    Dotsch
#
#                                                  cb_url logo_url facebook_url  \
# 3879  https://www.crunchbase.com/person/steven-dotsc...      NaN          NaN
#
#      twitter_url                              linkedin_url city region  \
# 3879         NaN  https://www.linkedin.com/in/stevendotsch  NaN    NaN
#
#      country_code featured_job_title featured_job_organization_name  \
# 3879          NaN        Team Member                EMAR Publishers
#
#             featured_job_organization_uuid
# 3879  0c3a1625-ea22-2b20-c6fc-0b67ae5dbfc1

# %%
org[org['uuid'] == '0c3a1625-ea22-2b20-c6fc-0b67ae5dbfc1']
# Out:
#                                       uuid             name          type  \
# 1886  0c3a1625-ea22-2b20-c6fc-0b67ae5dbfc1  EMAR Publishers  organization
#
#      primary_role                                             cb_url  \
# 1886      company  https://www.crunchbase.com/organization/wirele...
#
#                             domain                             homepage_url  \
# 1886  dividend-income-investor.com  http://www.dividend-income-investor.com
#
#                                                logo_url  \
# 1886  https://images.crunchbase.com/image/upload/t_c...
#
#                                            facebook_url  \
# 1886  http://www.facebook.com/Dividend-Income-Invest...
#
#                            twitter_url  \
# 1886  http://twitter.com/Investoretire
#
#                                   linkedin_url combined_stock_symbols    city  \
# 1886  https://www.linkedin.com/in/stevendotsch                    NaN  London
#
# ...

# %%
ppl[ppl['uuid'] == '08412334-e699-8536-d36b-98e26b5acf0a']
# Out:
#                                       uuid    type first_name last_name  \
# 9886  08412334-e699-8536-d36b-98e26b5acf0a  person     Damion   Hankejh
#
#                                                  cb_url  \
# 9886  https://www.crunchbase.com/person/damion-hanke...
#
#                                                logo_url facebook_url  \
# 9886  https://images.crunchbase.com/image/upload/t_c...          NaN
#
#                       twitter_url                         linkedin_url  \
# 9886  https://twitter.com/hankejh  https://www.linkedin.com/in/hankejh
#
#           city    region country_code  \
# 9886  New York  New York          USA
#
#                                   featured_job_title  \
# 9886  Founder, Chief Technology Officer and Chairman
#
#      featured_job_organization_name        featured_job_organization_uuid
# 9886                           HRDN  611895c7-8413-4177-9198-caa784a6c21e

# %%
org[org['uuid'] == '41d88d51-b45f-83c8-341a-957027e036f7']
# Out:
#                                       uuid         name          type  \
# 6080  41d88d51-b45f-83c8-341a-957027e036f7  ActiveCause  organization
#
#      primary_role                                             cb_url  \
# 6080      company  https://www.crunchbase.com/organization/active...
#
#                domain            homepage_url  \
# 6080  activecause.com  http://activecause.com
#
#                                                logo_url facebook_url  \
# 6080  https://images.crunchbase.com/image/upload/t_c...          NaN
#
#                          twitter_url                         linkedin_url  \
# 6080  http://twitter.com/activecause  https://www.linkedin.com/in/hankejh
#
#      combined_stock_symbols      city    region country_code  \
# 6080                    NaN  New York  New York          USA
#
#                                       short_description
# 6080  ActiveCause brings together nonprofits, corpor...

# %%
ppl[ppl['uuid'] == '3df69045-b562-00f6-034c-d638633b53a6']
# Out:
#                                        uuid    type first_name  \
# 18297  3df69045-b562-00f6-034c-d638633b53a6  person       Mark
#
#                                             last_name  \
# 18297  Nielsen, Wireless 21, Inc./Capistrano Ventures
#
#                                                   cb_url  \
# 18297  https://www.crunchbase.com/person/mark-nielsen...
#
#                                                 logo_url facebook_url  \
# 18297  https://images.crunchbase.com/image/upload/t_c...          NaN
#
#       twitter_url                                       linkedin_url    city  \
# 18297         NaN  http://www.linkedin.com/pub/mark-nielsen/0/680/87  Orange
#
#            region country_code featured_job_title  \
# 18297  California          USA           Chairman
#
#       featured_job_organization_name        featured_job_organization_uuid
# 18297                      AccuScore  8f0d6f78-e2a2-d3a4-0948-133d322cc5aa

# %%
org[org['uuid'] == '75ab1e6a-4abd-decf-a330-db2e6c18fad3']
# Out:
#                                       uuid            name          type  \
# 1857  75ab1e6a-4abd-decf-a330-db2e6c18fad3  European Union  organization
#
#      primary_role                                             cb_url  \
# 1857     investor  https://www.crunchbase.com/organization/europe...
#
#          domain      homepage_url  \
# 1857  europa.eu  http://europa.eu
#
#                                                logo_url  \
# 1857  https://images.crunchbase.com/image/upload/t_c...
#
#                                 facebook_url  \
# 1857  https://www.facebook.com/UEenVenezuela
#
#                                 twitter_url  \
# 1857  https://www.twitter.com/europeanunion
#
#                                          linkedin_url combined_stock_symbols  \
# 1857  https://www.linkedin.com/company/european-union                    NaN
#
#         city   region country_code  \
# 1857  London  England          GBR
#
#                                       short_description
# ...
