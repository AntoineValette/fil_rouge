# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import folium
from math import radians, sin, cos, sqrt, atan2

# %%
# Endpoint GraphDB
GRAPHDB_ENDPOINT = "http://localhost:7200/repositories/Fil_Rouge_DB"

# %%
# Fonction pour exécuter une requête SPARQL
def run_sparql_query(query):
    sparql = SPARQLWrapper(GRAPHDB_ENDPOINT)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    sparql.addParameter("sameAs", "false")
    results = sparql.query().convert()
    return results

# %%
# Fonction pour calculer la distance entre deux points en utilisant la formule de Haversine
def haversine_distance(lat1, lon1, lat2, lon2):
    # Convertir les degrés en radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1 
    dlon = lon2 - lon1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    # Rayon de la Terre en km
    km = 6371 * c
    return km * 1000  # conversion en mètres

# %%
# Pour chaque ville, compter le nombre d'organisations dans un rayon de 20 km (20 000 mètres)
def count_orgs_within_radius(city_lat, city_lon, city_country, orgs_df, radius=20000):
    # Filtrer uniquement les organisations du même pays
    orgs_in_country = orgs_df[orgs_df['country'] == city_country]
    distances = orgs_in_country.apply(lambda row: haversine_distance(city_lat, city_lon, row["lat"], row["lon"]), axis=1)
    return (distances <= radius).sum()

# %%
orgs_data = [
    {"org": "Marseille", "lat": 43.2965, "lon": 5.3698, "country": "France"},
    {"org": "Nanterre",  "lat": 48.8924, "lon": 2.1969, "country": "France"}
]
orgs_df = pd.DataFrame(orgs_data)

# Test pour la ville de Paris
paris_lat = 48.8566
paris_lon = 2.3522
paris_country = "France"

# Calcul du nombre d'organisations dans un rayon de 20 km autour de Paris
org_count = count_orgs_within_radius(paris_lat, paris_lon, paris_country, orgs_df, radius=20000)

print("Nombre d'organisations à moins de 20 km de Paris :", org_count)
# Out:
# Nombre d'organisations à moins de 20 km de Paris : 1

# %%
# Requête SPARQL pour récupérer les villes
cities_query = """
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX ns1: <http://www.semanticweb.org/fil_rouge_AntoineValette_GuillaumeRamirez/>

SELECT ?city ?cityName ?lat ?lon ?population ?country
WHERE {
  # ?city a ns1:City .
  # ?city ns1:population ?population .
  # ?city skos:prefLabel ?cityName .
  # ?city ns1:Latitude ?lat .
  # ?city ns1:Longitude ?lon .
  # ?city ns1:aPourPays ?country
  FILTER(?population >= 300000)
}
"""

# %%
# Requête SPARQL pour récupérer les organisations
orgs_query = """
PREFIX ns1: <http://www.semanticweb.org/fil_rouge_AntoineValette_GuillaumeRamirez/>

select ?org ?lat ?lon ?country where {
    # ?org a ns1:Organization .
    # ?org ns1:inCity ?city .
    # ?city ns1:Latitude ?lat .
    # ?city ns1:Longitude ?lon .
    # ?org ns1:inCountry ?country
}
"""

# %%
# Récupération des données des villes
cities_results = run_sparql_query(cities_query)
cities_data = []
for result in cities_results["results"]["bindings"]:
    cityName = result["cityName"]["value"]
    lat = float(result["lat"]["value"])
    lon = float(result["lon"]["value"])
    population = float(result["population"]["value"])
    country = result["country"]["value"]
    cities_data.append({
        "city": cityName,
        "lat": lat,
        "lon": lon,
        "population": population,
        "country": country
    })

# %%
cities_df = pd.DataFrame(cities_data)

# %%
cities_df.shape
# Out:
# (1814, 5)

# %%
# Récupération des données des organisations
orgs_results = run_sparql_query(orgs_query)
orgs_data = []
for result in orgs_results["results"]["bindings"]:
    org = result["org"]["value"]
    lat = float(result["lat"]["value"])
    lon = float(result["lon"]["value"])
    country = result["country"]["value"]
    orgs_data.append({
        "org": org,
        "lat": lat,
        "lon": lon,
        "country": country
    })

# %%
orgs_df = pd.DataFrame(orgs_data)

# %%
orgs_df.head()
# Out:
#                                                  org       lat        lon  \
# 0  https://www.crunchbase.com/organization/0023af...  45.52345 -122.67621
# 1  https://www.crunchbase.com/organization/002c5c...  37.56299 -122.32553
# 2  https://www.crunchbase.com/organization/00e435...  47.60621 -122.33207
# 3  https://www.crunchbase.com/organization/018d81...  37.83132 -122.28525
# 4  https://www.crunchbase.com/organization/0209db... -34.61315  -58.37723
#
#                                  country
# 0  https://www.geonames.org/countries/US
# 1  https://www.geonames.org/countries/US
# 2  https://www.geonames.org/countries/US
# 3  https://www.geonames.org/countries/US
# 4  https://www.geonames.org/countries/AR

# %%
# Appliquer le calcul pour chaque ville
cities_df["org_count"] = cities_df.apply(
    lambda row: count_orgs_within_radius(row["lat"], row["lon"], row["country"], orgs_df),
    axis=1
)
# Out:
#                city       lat        lon  population  \
# 160           Brent  51.55306   -0.30230    329100.0
# 1785         London  51.50853   -0.12574   8961989.0
# 114       Islington  51.53622   -0.10304    319143.0
# 1200  San Francisco  37.77493 -122.41942    864816.0
# 507         Oakland  37.80437 -122.27080    419267.0
#
#                                     country  org_count
# 160   https://www.geonames.org/countries/GB      12387
# 1785  https://www.geonames.org/countries/GB      12348
# 114   https://www.geonames.org/countries/GB      12322
# 1200  https://www.geonames.org/countries/US      11875
# 507   https://www.geonames.org/countries/US      11568

# %%
# Sélection des 5 villes ayant le plus d'organisations dans un rayon de 20 km,
# tout en s'assurant qu'elles soient séparées d'au moins 20 km les unes des autres.

selected_cities = []
sorted_cities = cities_df.sort_values(by="org_count", ascending=False)

for idx, row in sorted_cities.iterrows():
    too_close = False
    # Vérifier la distance entre la ville candidate et chacune des villes sélectionnées
    for selected in selected_cities:
        distance = haversine_distance(row["lat"], row["lon"], selected["lat"], selected["lon"])
        if distance < 20000:
            too_close = True
            break
    if not too_close:
        selected_cities.append(row)
    # Arrêter dès qu'on a 30 villes
    if len(selected_cities) >= 30:
        break

# Convertir la liste en DataFrame pour traitement ultérieur
top_cities = pd.DataFrame(selected_cities)
print(top_cities)
# Out:
#                city       lat        lon  population  \
# 160           Brent  51.55306   -0.30230    329100.0
# 1200  San Francisco  37.77493 -122.41942    864816.0
# 1732    Los Angeles  34.05223 -118.24368   3898747.0
# 1634          Paris  48.85341    2.34880   2138551.0
# 1096        Seattle  47.60621 -122.33207    737015.0
# 1682        Chicago  41.85003  -87.65005   2696555.0
# 332       Etobicoke  43.64415  -79.56985    365000.0
# 36          Vaughan  43.83610  -79.49827    306233.0
# 728      Karol Bāgh  28.65136   77.19072    505241.0
# 1475      San Diego  32.71571 -117.16472   1394928.0
# 897        Itabashi  35.74893  139.71497    584483.0
# 1524       Kawasaki  35.52056  139.71722   1538262.0
# 1782      Bengaluru  12.97194   77.59369   8443675.0
# 1710         Madrid  40.41650   -3.70256   3255944.0
# 1308         Dublin  53.33306   -6.24889   1024027.0
# 554        Tel Aviv  32.08088   34.78057    432892.0
# 194       Santa Ana  33.74557 -117.86783    335400.0
# 999        Portland  45.52345 -122.67621    652503.0
# 1761         Sydney -33.86785  151.20732   5231147.0
# 1715         Berlin  52.52437   13.41053   3426354.0
# 915       Anyang-si  37.39250  126.92694    595644.0
# 1073         Denver  39.73915 -104.98470    715522.0
# 1766      Singapore   1.28967  103.85007   5638700.0
# 1428          Thāne  19.19704   72.96355   1261517.0
# 1812        Beijing  39.90750  116.39723  18960744.0
# 1339      Goyang-si  37.65639  126.83500   1073069.0
# 923       Vancouver  49.24966 -123.11934    600000.0
# 1311       San Jose  37.33939 -121.89496   1026908.0
# 1553      Barcelona  41.38879    2.15899   1620343.0
# 1758      Melbourne -37.81400  144.96332   4917750.0
#
#                                     country  org_count
# 160   https://www.geonames.org/countries/GB      12387
# 1200  https://www.geonames.org/countries/US      11875
# 1732  https://www.geonames.org/countries/US       6058
# 1634  https://www.geonames.org/countries/FR       4698
# 1096  https://www.geonames.org/countries/US       4499
# 1682  https://www.geonames.org/countries/US       4437
# 332   https://www.geonames.org/countries/CA       3866
# 36    https://www.geonames.org/countries/CA       3718
# 728   https://www.geonames.org/countries/IN       3315
# 1475  https://www.geonames.org/countries/US       2825
# 897   https://www.geonames.org/countries/JP       2795
# 1524  https://www.geonames.org/countries/JP       2626
# 1782  https://www.geonames.org/countries/IN       2572
# 1710  https://www.geonames.org/countries/ES       2533
# 1308  https://www.geonames.org/countries/IE       2531
# 554   https://www.geonames.org/countries/IL       2491
# 194   https://www.geonames.org/countries/US       2436
# 999   https://www.geonames.org/countries/US       2419
# 1761  https://www.geonames.org/countries/AU       2336
# 1715  https://www.geonames.org/countries/DE       2288
# 915   https://www.geonames.org/countries/KR       2179
# 1073  https://www.geonames.org/countries/US       2143
# 1766  https://www.geonames.org/countries/SG       2119
# 1428  https://www.geonames.org/countries/IN       2072
# 1812  https://www.geonames.org/countries/CN       2049
# 1339  https://www.geonames.org/countries/KR       1990
# 923   https://www.geonames.org/countries/CA       1904
# 1311  https://www.geonames.org/countries/US       1868
# 1553  https://www.geonames.org/countries/ES       1780
# 1758  https://www.geonames.org/countries/AU       1745

# %%
# --- Visualisation avec Folium ---

# Créer la carte centrée sur (0, 0) avec un zoom arrière (par exemple, 2) et un fond de carte différent
m = folium.Map(location=[0, 0], zoom_start=2, tiles="CartoDB positron")

for idx, row in top_cities.iterrows():
    # Marker sous forme de CircleMarker pour une meilleure esthétique
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=8,  # taille du marker
        popup=folium.Popup(f"{row['city']} : {row['org_count']} organisations", parse_html=True),
        color="darkblue",
        fill=True,
        fill_color="lightblue",
        fill_opacity=0.7
    ).add_to(m)
    
    # Cercle de 20 km autour de la ville, avec un style plus discret
    folium.Circle(
        location=[row["lat"], row["lon"]],
        radius=20000,  # 20 km en mètres
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.1,
        weight=2
    ).add_to(m)

# Afficher la carte dans le notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd94bb0e383169b91f0779f180a3a014 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd94bb0e383169b91f0779f180a3a014&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd94bb0e383169b91f0779f180a3a014 = L.map(
#                 &quot;map_bd94bb0e383169b91f0779f180a3a014&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5cf2f86361127543ea98c3c6288dc187 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5cf2f86361127543ea98c3c6288dc187.addTo(map_bd94bb0e383169b91f0779f180a3a014);
#
#
#             var circle_marker_896bc48eab0e6faa4b053618798017d0 = L.circleMarker(
#                 [51.55306, -0.3023],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bd94bb0e383169b91f0779f180a3a014);
#
#
#         var popup_0f01aebb6a8012d240b027c3d7dd0441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_228b7338d0534b588299fce6fbc9c761 = $(`&lt;div id=&quot;html_228b7338d0534b588299fce6fbc9c761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brent : 12387 organisations&lt;/div&gt;`)[0];
#                 popup_0f01aebb6a8012d240b027c3d7dd0441.setContent(html_228b7338d0534b588299fce6fbc9c761);
#
#
#
#         circle_marker_896bc48eab0e6faa4b053618798017d0.bindPopup(popup_0f01aebb6a8012d240b027c3d7dd0441)
#         ;
#
#
#
#
#             var circle_89a47e912c9de8627ac85091badffcac = L.circle(
#                 [51.55306, -0.3023],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_bd94bb0e383169b91f0779f180a3a014);
#
#
#             var circle_marker_a23df9e80e0c67acbd268d32aed9d8c9 = L.circleMarker(
#                 [37.77493, -122.41942],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bd94bb0e383169b91f0779f180a3a014);
#
#
#         var popup_095e8a33a56314594defda86ed8f519d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83f2bd4d0891cc793829a623ddf27ebc = $(`&lt;div id=&quot;html_83f2bd4d0891cc793829a623ddf27ebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco : 11875 organisations&lt;/div&gt;`)[0];
#                 popup_095e8a33a56314594defda86ed8f519d.setContent(html_83f2bd4d0891cc793829a623ddf27ebc);
#
#
#
#         circle_marker_a23df9e80e0c67acbd268d32aed9d8c9.bindPopup(popup_095e8a33a56314594defda86ed8f519d)
#         ;
#
#
#
#
#             var circle_a0277f339c802e3c76bc45c473a1b2f3 = L.circle(
#                 [37.77493, -122.41942],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20000, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_bd94bb0e383169b91f0779f180a3a014);
#
#
#             var circle_marker_83f4ad98e56e7bb51a617848589f25d0 = L.circleMarker(
#                 [34.05223, -118.24368],
